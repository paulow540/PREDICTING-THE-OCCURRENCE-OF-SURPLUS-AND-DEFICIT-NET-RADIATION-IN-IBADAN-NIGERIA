# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("2021.xlsx")
data.head()

# %%
data.info()

# %%
okay = []
def model():
    for i in data["Day"]:
        dr = 1+0.033*np.cos(2*22/7*i/365)
#         d = 23.45*np.sin(360*284+i/365)
        d = 0.409 * np.sin(2*i)
        w = np.arccos(-np.tan(7.3775)*np.tan(d))
        ra = (24*3600)/(22/7)*dr*(np.cos(7.3775)*np.cos(d)*np.sin(w) + ((w*22/7)/180)*np.sin(7.3775)*np.sin(d))
        okay.append(w)

# %%
model()
# np.arccos(-0.8107051217715388)
# Out:
# <ipython-input-67-f08557457d7d>:6: RuntimeWarning: invalid value encountered in arccos
#   w = np.arccos(-np.tan(7.3775)*np.tan(d))

# %%
okay
# Out:
# [2.131359696271823,
#  2.302437971197885,
#  2.516151839793385,
#  2.862119537771656,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.131359696271823,
#  2.302437971197885,
#  2.516151839793385,
#  2.862119537771656,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.131359696271823,
#  2.302437971197885,
#  2.516151839793385,
#  2.862119537771656,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.131359696271823,
#  2.302437971197885,
#  2.516151839793385,
#  2.862119537771656,
#  nan,
#  nan,
#  nan,
# ...

# %%
# 1+0.033*np.cos(2*22/7*1/365)
d = 23.45*np.sin(360*284+i/365)

# %%
d
# Out:
# 2.1920218668247218
